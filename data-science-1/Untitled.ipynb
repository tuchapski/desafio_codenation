# %%
import numpy as np
import scipy.stats as sct
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import Math, Latex
# for displaying images
from IPython.core.display import Image

# %%
# %matplotlib inline

# %%
sns.set(color_codes = True)
sns.set(rc={'figure.figsize':(5,5)})

# %%
n = 10000
start = 10
width = 20

data_uniform = sct.uniform.rvs(size=n, loc=start, scale=width)

ax = sns.distplot(data_uniform,
                  bins=100,
                  kde=True,
                  color='red',
                  hist_kws={"linewidth": 15, 'alpha':1})

ax.set(xlabel='Uniform Distribution', ylabel='Frequency')
# Out:
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Uniform Distribution')]

# %%
from scipy.stats import norm

data_normal = norm.rvs(size=10000, loc=50, scale=5)

ax = sns.distplot(data_normal,
                  bins=100,
                  kde=True,
                  color='skyblue',
                  hist_kws={"linewidth": 15,'alpha':1})
ax.set(xlabel='Normal Distribution', ylabel='Frequency')
# Out:
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Normal Distribution')]

# %%
data_normal.mean(), data_normal.std()
# Out:
# (49.97401747451171, 4.988696636794344)

# %%
sct.norm.pdf(42, 50, 5)
# Out:
# 0.02218416693589111

# %%
sct.norm.cdf(60,  50, 5)
# Out:
# 0.9772498680518208
